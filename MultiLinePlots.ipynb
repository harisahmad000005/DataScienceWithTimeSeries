# %%
# %matplotlib inline

import numpy as np

import matplotlib.pyplot as plt

# %%
x = np.arange(10)
plt.plot(x,x**2)

# %%
x = np.arange(10)
plt.plot(x,x**2)
plt.plot(x,x**3)

# %%
x = np.arange(10)
plt.plot(x,x**2)
plt.plot(x,x**3) 
plt.plot(x,x*2)
plt.plot(x,2**x)

# %%
plt.plot(x,x**2,x,x**3,x,x*2,x,2**x)

# %%
x = np.array([[1,2,6],[4,5,3]])
plt.plot(x)

# %%
x = np.array([[1,2,6,2],[4,5,3,7]])
plt.plot(x)

# %%
data = np.random. randn(2,10)
print(data)
plt.plot(data[0],data[1])
# Out:
# [[-1.54188386 -0.6260026   0.55967647 -1.61431074 -0.65188538 -0.7061905
#    0.79085285 -0.42701553 -0.07098714 -0.47451499]
#  [ 0.93988264 -0.07773091 -0.83466401  0.50634205 -1.42151298  0.41049443
#   -0.09659221 -0.58998361  1.08452378 -0.6020711 ]]
